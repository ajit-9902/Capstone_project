# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('crime_datasets.csv')

# %%
df.head()
# Out:
#             State/UT  Year  population(total)     Rural     Urban     Tot_M  \
# 0       A& N ISLANDS  2001             356152    239954    116198    192972
# 1     ANDHRA PRADESH  2001           76210007  55401067  20808940  38527413
# 2  ARUNACHAL PRADESH  2001            1097968    870087    227881    579941
# 3              ASSAM  2001           26655528  23216288   3439240  13777037
# 4              BIHAR  2001           82998509  74316709   8681800  43243795
#
#       Tot_F       P_LIT       M_LIT     F_LIT  ...  \
# 0    163180    253135.0    146831.0    106304  ...
# 1  37682594  39934323.0  23444788.0  16489535  ...
# 2    518027    484785.0    303281.0    181504  ...
# 3  12878491  14015354.0   8188697.0   5826657  ...
# 4  39754714  31109577.0  20644376.0  10465201  ...
#
#    IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 0                                            0                            0
# 1                                            7                         7400
# 2                                            0                            0
# 3                                            0                         2010
# 4                                           83                         2406
#
#    OTHER IPC CRIMES  TOTAL IPC CRIMES  Total Crimes  tot_crimes_sc  \
# 0               323               658          1386              0
# 1             34344            130089        278982           2933
# 2               618              2342          5243              0
# 3              9315             36877         81418              6
# 4             36667             88432        189612           1303
#
#    total crime against women  Total crimes against STs  \
# 0                       34.0                       1.0
# 1                    13669.0                     512.0
# 2                      180.0                      72.0
# 3                     4048.0                       0.0
# 4                     4489.0                      83.0
#
#    Total crime against children  Crime Rate
# 0                           0.0  184.752578
# 1                         270.0  170.698055
# 2                           0.0  213.303120
# 3                          18.0  138.346537
# 4                          83.0  106.546492
#
# [5 rows x 48 columns]

# %% [markdown]
# I Have collected Data from several Websites, the data gives the crimes from 2001 to 2012 i have also gone through the git hub for data sets which i have mentioned the link

# %% [markdown]
# - https://github.com/sahilichake/Indian-Crime-Data-Analysis-Forecasting/blob/main/crime.csv
# - https://en.wikipedia.org/wiki/List_of_states_in_India_by_past_population
# - https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area
# - https://en.wikipedia.org/wiki/List_of_Indian_states_and_union_territories_by_literacy_rate
# - https://socialjustice.gov.in/common/76669
# - http://cyberjournalist.org.in/census/cenindia.html
# - https://www.indiastat.com/specimen-tables/geographical-data
# - https://www.wbhealth.gov.in/other_files/2007/14_5.html
# - https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_population
